# %% [markdown]
# # 3. LangChain基础

# %% [markdown]
# ## 调试LLM应用

# %% [markdown]
# ### 不启用调试功能

# %%
from langchain_community.llms import Ollama

llm = Ollama(model="qwen:1.8b")

llm.invoke("你是谁？")
# Out:
# /tmp/ipykernel_33865/1211169711.py:3: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm=Ollama(model="qwen:1.8b")
# '我是来自阿里云的大规模语言模型，我叫通义千问。我可以回答各种文本相关的问题，涉及领域广泛，包括但不限于科技、文化、历史、社会等。无论您有什么问题想要咨询，通义千问都会尽全力提供最准确的答案和信息。如果您有任何其他关于通义千问或者人工智能技术的问题，请随时向我提问。感谢您的关注和支持！'

# %% [markdown]
# ### 使用debug参数调试

# %%
from langchain_community.llms import Ollama
import langchain
from langchain.globals import set_debug

llm = Ollama(model="qwen:1.8b")
langchain.debug = True  # 或 set_debug(True)

llm.invoke("你是谁？")
# Out:
# [llm/start] [llm:Ollama] Entering LLM run with input:
# {
#   "prompts": [
#     "你是谁？"
#   ]
# }
# [llm/end] [llm:Ollama] [34.96s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "我是来自阿里云的大规模语言模型，我叫通义千问。通义千问是阿里巴巴集团研发的语言模型系列之一，由通义大模型、通义小模型等子集组成，能够进行自然语言的理解、生成和解释。\n\n通义千问能够回答关于世界历史、科学知识、文化历史等方面的问题。此外，通义千问还能够根据上下文提供与问题相关的信息或观点，从而实现文本理解和生成的目标。\n\n总的来说，通义千问是一款能够进行自然语言理解、生成和解释的大规模语言模型系列，是阿里云在人工智能领域的重要研究成果之一。",
#         "generation_info": {
#           "model": "qwen:1.8b",
#           "created_at": "2025-02-17T05:18:42.330744908Z",
#           "response": "",
#           "done": true,
#           "done_reason": "stop",
#           "context": [
#             151644,
#             872,
#             198,
#             105043,
#             100165,
#             11319,
#             151645,
#             198,
#             151644,
#             77091,
#             198,
#             104198,
#             101919,
#             102661,
#             99718,
#             104197,
#             100176,
#             102064,
#             104949,
#             3837,
#             35946,
#             99882,
#             31935,
#             64559,
#             99320,
#             56007,
#             1773,
#             31935,
#             64559,
#             99320,
#             56007,
#             20412,
#             107076,
#             100338,
#             100048,
#             109824,
#             104949,
#             100187,
#             100653,
#             3837,
#             67071,
#             31935,
#             64559,
#             26288,
#             104949,
#             5373,
#             31935,
#             64559,
#             30709,
#             104949,
#             49567,
#             44729,
#             42067,
#             101286,
#             3837,
#             100006,
#             71817,
#             99795,
#             102064,
#             108894,
#             5373,
#             43959,
#             33108,
#             104136,
#             1773,
#             198,
#             198,
#             31935,
#             64559,
#             99320,
#             56007,
#             100006,
#             102104,
#             101888,
#             99489,
#             100022,
#             5373,
#             99891,
#             100032,
#             5373,
#             99348,
#             100022,
#             102159,
#             103936,
#             1773,
#             104043,
#             3837,
#             31935,
#             64559,
#             99320,
#             56007,
#             97706,
#             100006,
#             100345,
#             102285,
#             16744,
#             99553,
#             57218,
#             86119,
#             78556,
#             105427,
#             57191,
#             101313,
#             3837,
#             101982,
#             101884,
#             108704,
#             115167,
#             43959,
#             104820,
#             1773,
#             198,
#             198,
#             116880,
#             3837,
#             31935,
#             64559,
#             99320,
#             56007,
#             106955,
#             100006,
#             71817,
#             99795,
#             102064,
#             101128,
#             5373,
#             43959,
#             33108,
#             104136,
#             104197,
#             100176,
#             102064,
#             104949,
#             100187,
#             3837,
#             20412,
#             102661,
#             99718,
#             18493,
#             104455,
#             100650,
#             101945,
#             113352,
#             100653,
#             1773
#           ],
#           "total_duration": 34952698295,
#           "load_duration": 25688959,
#           "prompt_eval_count": 11,
#           "prompt_eval_duration": 471000000,
#           "eval_count": 131,
#           "eval_duration": 34454000000
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null,
#   "type": "LLMResult"
# }
# '我是来自阿里云的大规模语言模型，我叫通义千问。通义千问是阿里巴巴集团研发的语言模型系列之一，由通义大模型、通义小模型等子集组成，能够进行自然语言的理解、生成和解释。\n\n通义千问能够回答关于世界历史、科学知识、文化历史等方面的问题。此外，通义千问还能够根据上下文提供与问题相关的信息或观点，从而实现文本理解和生成的目标。\n\n总的来说，通义千问是一款能够进行自然语言理解、生成和解释的大规模语言模型系列，是阿里云在人工智能领域的重要研究成果之一。'

# %% [markdown]
# ### 使用verbose参数调试

# %%
from langchain_community.llms import Ollama
import langchain
from langchain.globals import set_verbose

llm = Ollama(model="qwen:1.8b")
langchain.verbose = True  # 或 set_verbose(True)

llm.invoke("你是谁？")
# Out:
# [llm/start] [llm:Ollama] Entering LLM run with input:
# {
#   "prompts": [
#     "你是谁？"
#   ]
# }
# [llm/end] [llm:Ollama] [52.95s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "我是来自阿里云的超大规模语言模型，我的名字叫通义千问。通义千问是阿里巴巴集团自主研发的大规模语言模型，也是全球首个能够独立思考、表达观点并能完成问答任务的人工智能模型。\n\n通义千问基于最先进的自然语言处理技术，包括神经网络架构、大量文本语料库的建设等，实现了对复杂多变的语言现象进行理解和生成的能力。同时，通义千问还具备自我修正和适应环境变化的能力，能够不断学习、进化和提升自身性能和应用价值。\n\n通义千问是全球首个能够独立思考、表达观点并能完成问答任务的人工智能模型。作为阿里云自主研发的大规模语言模型，通义千问以其强大的语言理解和生成能力，为阿里巴巴集团的各种业务场景提供了广泛的支持和帮助。随着人工智能技术的不断发展和完善，通义千问也将继续发挥其在大规模语言模型领域的关键作用，为推动人工智能技术的持续发展与广泛应用，作出新的更大的贡献和努力。",
#         "generation_info": {
#           "model": "qwen:1.8b",
#           "created_at": "2025-02-17T05:23:16.814676372Z",
#           "response": "",
#           "done": true,
#           "done_reason": "stop",
#           "context": [
#             151644,
#             872,
#             198,
#             105043,
#             100165,
#             11319,
#             151645,
#             198,
#             151644,
#             77091,
#             198,
#             104198,
#             101919,
#             102661,
#             99718,
#             9370,
#             71304,
#             105483,
#             102064,
#             104949,
#             3837,
#             97611,
#             101419,
#             99882,
#             31935,
#             64559,
#             99320,
#             56007,
#             1773,
#             31935,
#             64559,
#             99320,
#             56007,
#             20412,
#             107076,
#             100338,
#             111411,
#             104197,
#             100176,
#             102064,
#             104949,
#             3837,
#             100000,
#             100357,
#             105992,
#             100006,
#             102024,
#             104107,
#             5373,
#             102124,
#             101313,
#             62926,
#             26232,
#             60548,
#             111436,
#             88802,
#             100623,
#             48692,
#             100168,
#             104949,
#             1773,
#             198,
#             198,
#             31935,
#             64559,
#             99320,
#             56007,
#             104210,
#             118803,
#             99795,
#             102064,
#             54542,
#             99361,
#             3837,
#             100630,
#             102398,
#             71356,
#             106379,
#             5373,
#             100722,
#             108704,
#             72881,
#             41406,
#             44956,
#             9370,
#             99403,
#             49567,
#             3837,
#             104415,
#             32664,
#             102181,
#             42140,
#             74040,
#             109824,
#             102060,
#             71817,
#             115167,
#             43959,
#             104426,
#             1773,
#             91572,
#             3837,
#             31935,
#             64559,
#             99320,
#             56007,
#             97706,
#             102094,
#             104049,
#             108271,
#             33108,
#             104117,
#             99719,
#             100682,
#             104426,
#             3837,
#             100006,
#             99607,
#             100134,
#             5373,
#             109205,
#             33108,
#             100341,
#             101960,
#             102111,
#             33108,
#             99892,
#             100162,
#             1773,
#             198,
#             198,
#             31935,
#             64559,
#             99320,
#             56007,
#             20412,
#             100357,
#             105992,
#             100006,
#             102024,
#             104107,
#             5373,
#             102124,
#             101313,
#             62926,
#             26232,
#             60548,
#             111436,
#             88802,
#             100623,
#             48692,
#             100168,
#             104949,
#             1773,
#             100622,
#             102661,
#             99718,
#             111411,
#             104197,
#             100176,
#             102064,
#             104949,
#             3837,
#             31935,
#             64559,
#             99320,
#             56007,
#             109859,
#             104795,
#             102064,
#             115167,
#             43959,
#             99788,
#             3837,
#             17714,
#             107076,
#             100338,
#             107135,
#             103923,
#             102122,
#             104257,
#             100789,
#             106100,
#             33108,
#             100364,
#             1773,
#             101067,
#             104455,
#             99361,
#             9370,
#             114133,
#             112581,
#             3837,
#             31935,
#             64559,
#             99320,
#             56007,
#             105195,
#             100640,
#             100689,
#             41146,
#             18493,
#             105483,
#             102064,
#             104949,
#             104799,
#             99936,
#             100154,
#             3837,
#             17714,
#             101890,
#             104455,
#             99361,
#             9370,
#             100652,
#             99185,
#             57218,
#             112306,
#             3837,
#             104279,
#             100676,
#             106155,
#             102007,
#             33108,
#             101066,
#             1773
#           ],
#           "total_duration": 52929346027,
#           "load_duration": 27054025,
#           "prompt_eval_count": 11,
#           "prompt_eval_duration": 383000000,
#           "eval_count": 213,
#           "eval_duration": 52518000000
#         },
#         "type": "Generation"
#       }
#     ]
#   ],
#   "llm_output": null,
#   "run": null,
#   "type": "LLMResult"
# }
# '我是来自阿里云的超大规模语言模型，我的名字叫通义千问。通义千问是阿里巴巴集团自主研发的大规模语言模型，也是全球首个能够独立思考、表达观点并能完成问答任务的人工智能模型。\n\n通义千问基于最先进的自然语言处理技术，包括神经网络架构、大量文本语料库的建设等，实现了对复杂多变的语言现象进行理解和生成的能力。同时，通义千问还具备自我修正和适应环境变化的能力，能够不断学习、进化和提升自身性能和应用价值。\n\n通义千问是全球首个能够独立思考、表达观点并能完成问答任务的人工智能模型。作为阿里云自主研发的大规模语言模型，通义千问以其强大的语言理解和生成能力，为阿里巴巴集团的各种业务场景提供了广泛的支持和帮助。随着人工智能技术的不断发展和完善，通义千问也将继续发挥其在大规模语言模型领域的关键作用，为推动人工智能技术的持续发展与广泛应用，作出新的更大的贡献和努力。'
