# %% [markdown]
# # 4. 管理LLM的接口和解析输出

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## 4.1. 认识LLM的接口

# %% [markdown]
# ### 4.1.1 认识基础模型的接口

# %% [markdown]
# #### call()方法

# %%
"""
pip install openai
export OPENAI_API_KEY="... ..."         # 配置成环境变量
from langchain.llms import OpenAI
llm = OpenAI()

from langchain.llms import OpenAI
llm = OpenAI(openai_api_key="... ...")  # 不配置成环境变量
"""

# 上面是配置OpenAI密钥的过程，这里使用本地的Ollama

from langchain_community.llms import Ollama

llm = Ollama(model="gpt-oss:20b")
print(llm("哪些城市曾是中国的首都？"))
# Out:
# /root/GithubProjects/HelloAI/Book/LangChain实战派/venv/lib/python3.11/site-packages/langchain_core/_api/deprecation.py:119: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 0.3.0. Use invoke instead.
#   warn_deprecated(
# **中国历史上曾担任“首都”或国家政治中心的主要城市（按时间先后顺序概览）**
#
# | 时期（或朝代） | 首都城市 | 主要在座年份（大致） | 说明 |
# |---------------|----------|---------------------|------|
# | 秦朝（221–206 BC） | 西安（咸阳） | 221–206 | 秦始皇统一六国后将首都设在咸阳。 |
# | 西汉（206 BC–9 AD） | 西安（咸阳） | 206 BC–9 | 维持咸阳为国都。 |
# | 东汉（25–220） | 先在西安（25–190），后迁至洛阳（190–220） | 25–220 | 190 年因内乱、瘟疫迁都洛阳。 |
# | 魏晋南北朝（3–6世纪） | 主要为洛阳、长安、扬州、南京等 | 300–600 | 各朝代多次更迭：<br>• 魏、晋、东晋都以洛阳或长安为都；<br>• 南朝各国（东吴、东晋、刘宋、南齐、南梁、陈）以南京（建康）为都。 |
# | 隋朝（581–618） | 长安（581–604），后迁洛阳（604–618） | 581–618 | 隋文帝先定长安，后因南方兴起迁至洛阳。 |
# | 唐朝（618–907） | 长安（618–756），后迁洛阳（756–907） | 618–907 | 武则天、安史之乱后迁都洛阳。 |
# | 北魏（386–535） | 洛阳（386–535），后迁雍州（即今北京）535–554 | 386–535 | 北魏迁都后，洛阳被迁出。 |
# ...

# %% [markdown]
# #### generate()方法

# %%
# llm = Ollama(model="gpt-oss:20b")
llm = Ollama(model="deepseek-r1:8b")
llm_result = llm.generate(["给我讲个笑话","给我朗诵首诗"]*5)
len(llm_result.generations)
# Out:
# 10

# %%
llm_result.generations[0]
# Out:
# [GenerationChunk(text='好的，有一个笑话，希望你笑得出来：\n\n有一天，一只猫和一只狗在院子里吵架。  \n猫说：“你身上的味道好重啊！”  \n狗不服气地说：“那你身上的灰尘呢？”  \n\n🐱😂🐶  \n\n（笑点在于双方都有理，但狗的反击更直接，有点无厘头）', generation_info={'model': 'deepseek-r1:8b', 'created_at': '2026-01-02T02:43:06.361398428Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [151669, 104169, 99526, 18947, 109959, 151670, 151667, 198, 106287, 3837, 20002, 104029, 99526, 18947, 109959, 3837, 104544, 20412, 99172, 104261, 100158, 100631, 92133, 27442, 99350, 44729, 1773, 87267, 2565, 99601, 104037, 109666, 3837, 100631, 104753, 100832, 116405, 27442, 100415, 3837, 74763, 104560, 99172, 81705, 97611, 108460, 98650, 1773, 101260, 102066, 3837, 99526, 109959, 104104, 100405, 99518, 107071, 9370, 104199, 75768, 3407, 20002, 80443, 105146, 109959, 31905, 3837, 99999, 49828, 30767, 18947, 105600, 111177, 9370, 109959, 1773, 101239, 21515, 109959, 102119, 99792, 99464, 3837, 100047, 101128, 3837, 101885, 2073, 100737, 854, 99487, 105167, 112973, 99348, 99859, 120211,
# ...

# %%
llm_result.generations[-1]
# Out:
# [GenerationChunk(text='好的，我为你朗诵一首原创诗歌：\n\n《光之序曲》\n光从指缝间溢出\n像未写完的日记\n在晨露里折页\n蝴蝶用翅膀丈量距离\n风停驻的刹那\n整片森林开始破茧\n星辰在眼底编织星轨\n而大地始终沉默\n像首未完成的诗\n等待某个音节破开寂静\n潮声退去又涌来\n笛声穿过季风\n月光在水面练习舞蹈\n星芒刺破凝视\n所有未完成的故事\n都在黑暗中等待破晓\n而我是一首未完的歌\n在时间的琴弦上\n轻轻拨动\n\n（注：这是我即兴创作的一首诗，意象跳跃但追求内在韵律。如果需要调整风格或主题，可以告诉我具体方向，我会为你重新创作。）', generation_info={'model': 'deepseek-r1:8b', 'created_at': '2026-01-02T02:43:24.338184683Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [151669, 104169, 118585, 59975, 100045, 151670, 151667, 198, 106287, 3837, 20002, 104029, 118585, 108462, 100045, 1773, 99487, 34859, 106390, 100405, 3837, 77288, 101423, 87267, 18830, 108464, 99559, 5122, 2565, 87267, 100009, 99172, 49187, 104383, 90172, 101607, 87335, 3837, 108542, 18493, 104243, 26232, 100771, 113178, 9370, 100045, 3837, 100631, 103148, 99172, 81705, 97611, 98380, 108758, 3407, 106350, 101041, 118585, 46451, 12857, 9370, 100045, 87267, 104250, 104199, 33071, 3837, 104530, 91676, 99355, 104223, 108462, 100045, 36407, 104493,
# ...

# %%
print(llm_result.llm_output)
# Out:
# None

# %% [markdown]
# ### 4.1.2 认识聊天模型的接口

# %%
from langchain.chat_models import ChatOllama
from langchain.schema import(
    AIMessage,
    HumanMessage,
    SystemMessage
)

# %% [markdown]
# #### call()方法

# %%
llm.chat([HumanMessage(content="把这句话从汉语翻译成英语：我喜欢编程。")])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 llm.chat([HumanMessage(content="把这句话从汉语翻译成英语：我喜欢编程。")])
#
# AttributeError: 'Ollama' object has no attribute 'chat'

# %% [markdown]
# #### generate()方法
